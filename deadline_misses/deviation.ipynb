# %%
import numpy as np
import pandas as pd

nominal = pd.read_csv("./p2_1hit0miss.tsv", sep="\t")
two_miss = pd.read_csv("./p2_1hit2miss.tsv", sep="\t")

dy = nominal['y'] - two_miss['y']
print(max(dy), np.argmax(dy))
# Out:
# 0.013924979422741499 146

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(nominal['y'])
plt.plot(two_miss['y'])
plt.legend(['nominal', '2 miss']);

# %%
plt.plot(np.abs(two_miss['y'] - nominal['y']))
plt.legend(['deviation']);

# %%
print(np.abs(two_miss['y'] - nominal['y']).to_string())
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000153
# 4      0.000460
# 5      0.000795
# 6      0.001203
# 7      0.001704
# 8      0.002305
# 9      0.003000
# 10     0.003783
# 11     0.004641
# 12     0.005563
# 13     0.006537
# 14     0.007555
# 15     0.008606
# 16     0.009684
# 17     0.010782
# 18     0.011586
# 19     0.012092
# 20     0.012550
# 21     0.012867
# 22     0.012998
# 23     0.012929
# 24     0.012666
# 25     0.012224
# 26     0.011625
# 27     0.010893
# 28     0.010048
# 29     0.009113
# 30     0.008104
# 31     0.007038
# 32     0.005926
# 33     0.004780
# 34     0.003608
# 35     0.002417
# 36     0.001211
# 37     0.000005
# 38     0.001228
# 39     0.002144
# 40     0.002755
# 41     0.003311
# 42     0.003720
# 43     0.003939
# 44     0.003953
# 45     0.003769
# 46     0.003404
# 47     0.003190
# 48     0.003149
# 49     0.003362
# 50     0.003629
# 51     0.004071
# 52     0.004749
# 53     0.005681
# 54     0.006550
# ...
